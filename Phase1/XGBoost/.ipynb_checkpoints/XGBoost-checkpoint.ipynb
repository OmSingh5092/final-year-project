# %%
import numpy as np
import pandas as pd
import xgboost as xgb

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("../../DataSets/data_set_dra_updated.csv")

X = pd.DataFrame(dataset.iloc[:, 0:6].values)
y = dataset.iloc[:, 6].values

# Making train and test sets for both X and y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 123)


# Instantiate an XGBoost object with hyperparameters
xgb_reg = xgb.XGBRegressor(n_estimators=100, objective='reg:linear', seed = 123)

# Train the model with train data sets
xgb_reg.fit(X_train, y_train)
# Out:
# C:\Users\omsin\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [18:42:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=16,
#              num_parallel_tree=1, objective='reg:linear', predictor='auto',
#              random_state=123, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=123, subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
y_pred = xgb_reg.predict(X_test) # Predictions
y_true = y_test # True values

# %%
# Prediction Metrics

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error

MSE = mse(y_true, y_pred)
R2 = r2_score(y_true, y_pred)
MAX_ERROR = max_error(y_true, y_pred);
MEAN_ABSOLUTE_ERROR = mean_absolute_error(y_true, y_pred)


print("Mean Squared Error", MSE)
print("R-Squared: ", R2)
print("Max Error", MAX_ERROR);
print("Mean Absolute Error", MEAN_ABSOLUTE_ERROR);
# Out:
# Mean Squared Error 2.657638884322736
# R-Squared:  0.9218059352445804
# Max Error 29.517816357998043
# Mean Absolute Error 0.9084541022264804

# %%
# Accuracy Plot

import matplotlib.pyplot as plt

def generatePredictionPlot(y_pred, y_test):
    plt.scatter(x=y_test, y=y_pred, c='navy', alpha=0.6)
    plt.plot(y_pred, y_pred,color='cyan')
    plt.title('Predicted vs Actual values')
    plt.xlabel('Actual values')
    plt.ylabel('Predicted values')
    plt.show()
    
generatePredictionPlot(y_pred, y_test)

# %%
# Data Samples

d1 = [14.10, 14.55, 2.25, 2.6, 2.42] #HFSS S11 = -0.37
d2 = [13.04, 13.30, 2.3, 2.7, 1.84] # HFSS S11 = -0.43
d3 = [13.19, 13.74, 2.7, 2.45, 1.95] # HFSS S11 = -0.44
d4 = [14.42, 13.12, 2.4, 2.8, 2.41] # HFSS S11 = -0.51
d5 = [13.86, 14.57, 2.8, 2.1, 2.56] #HFSS S11 = -0.77

# Predictions
preds = xgb_reg.predict(pd.DataFrame([d1,d2,d3,d4,d5],columns = [0,1,2,3,4]))

print("Predictions", preds);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <module>
#       7 d5 = [13.86, 14.57, 2.8, 2.1, 2.56] #HFSS S11 = -0.77
#       9 # Predictions
# ---> 10 preds = xgb_reg.predict(pd.DataFrame([d1,d2,d3,d4,d5],columns = [0,1,2,3,4]))
#      12 print("Predictions", preds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:881, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     879 if self._can_use_inplace_predict():
#     880     try:
# --> 881         predts = self.get_booster().inplace_predict(
#     882             data=X,
#     883             iteration_range=iteration_range,
#     884             predict_type="margin" if output_margin else "value",
#     885             missing=self.missing,
#     886             base_margin=base_margin,
#     887             validate_features=validate_features,
#     888         )
#     889         if _is_cupy_array(predts):
#     890             import cupy     # pylint: disable=import-error
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:2018, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2014         raise TypeError(
#    2015             "`shape` attribute is required when `validate_features` is True."
#    2016         )
#    2017     if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 2018         raise ValueError(
#    2019             f"Feature shape mismatch, expected: {self.num_features()}, "
#    2020             f"got {data.shape[1]}"
#    2021         )
#    2023 from .data import _is_pandas_df, _transform_pandas_df
#    2024 from .data import _array_interface
#
# ValueError: Feature shape mismatch, expected: 6, got 5

# %%
# Generating random data sets

import numpy
import pandas

SAMPLE_SIZE = 10

def randomSample(low, high, size):
    rand_rad = numpy.random.uniform(low, high, size)
    for i in range(0, rand_rad.size):
        rand_rad[i] = round(rand_rad[i], 2)
    return rand_rad

rand_rad = randomSample(13, 15, SAMPLE_SIZE)
rand_height = randomSample(13, 15, SAMPLE_SIZE)
rand_freq = randomSample(1, 5, SAMPLE_SIZE)
rand_w1 = randomSample(2.5, 3.5, SAMPLE_SIZE)
rand_w2 = randomSample(2.5, 3.5, SAMPLE_SIZE)

rand_x = []
for i in range(0,SAMPLE_SIZE):
    rand_x.append([rand_height[i], rand_rad[i], rand_w1[i], rand_w2[i], rand_freq[i]])

y_pred_rand = xgb_reg.predict(pd.DataFrame(rand_x,columns = [0,1,2,3,4]))

output = []
for i in range(0, SAMPLE_SIZE):
    output.append([rand_height[i], rand_rad[i], rand_w1[i], rand_w2[i], rand_freq[i], y_pred_rand[i]])
    
# Creating Dataframe
output_df = pandas.DataFrame(output, columns= ["Height", "Radius", "W1", "W2", "Frequency", "S11"])
print("Predicted Values for random samples\n")
print(output_df)
